# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Farhad.lotfi\Desktop\pandas_course\S05-S08\Data\movies.csv')
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7661                                    More to Life    NaN      Drama  2020
# 7662                                     Dream Round    NaN     Comedy  2020
# 7663                                   Saving Mbango    NaN      Drama  2020
# 7664                                    It's Just Us    NaN      Drama  2020
# 7665                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.shape
# Out:
# (7666, 16)

# %%
df.dtypes
# Out:
# name                object
# rating              object
# genre               object
# year                 int64
# release_date        object
# release_country     object
# score              float64
# votes              float64
# director            object
# writer              object
# star                object
# country             object
# budget             float64
# gross              float64
# company             object
# runtime            float64
# dtype: object

# %%
df.iloc[0]
# Out:
# name                   The Shining
# rating                           R
# genre                        Drama
# year                          1980
# release_date         June 13, 1980
# release_country      United States
# score                          8.4
# votes                     927000.0
# director           Stanley Kubrick
# writer                Stephen King
# star                Jack Nicholson
# country             United Kingdom
# budget                  19000000.0
# gross                   46998772.0
# company               Warner Bros.
# runtime                      146.0
# Name: 0, dtype: object

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
df.iloc[100]
# Out:
# name                    Excalibur
# rating                          R
# genre                   Adventure
# year                         1981
# release_date       April 10, 1981
# release_country     United States
# score                         7.4
# votes                     59000.0
# director             John Boorman
# writer              Thomas Malory
# star                  Nigel Terry
# country            United Kingdom
# budget                 11000000.0
# gross                  34971136.0
# company                Cinema '84
# runtime                     140.0
# Name: 100, dtype: object

# %%
df.loc[0]
# Out:
# name                   The Shining
# rating                           R
# genre                        Drama
# year                          1980
# release_date         June 13, 1980
# release_country      United States
# score                          8.4
# votes                     927000.0
# director           Stanley Kubrick
# writer                Stephen King
# star                Jack Nicholson
# country             United Kingdom
# budget                  19000000.0
# gross                   46998772.0
# company               Warner Bros.
# runtime                      146.0
# Name: 0, dtype: object

# %%
df = pd.read_csv(r'C:\Users\Farhad.lotfi\Desktop\pandas_course\S05-S08\Data\movies.csv',index_col='name')
df
# Out:
#                                                rating      genre  year  \
# name
# The Shining                                         R      Drama  1980
# The Blue Lagoon                                     R  Adventure  1980
# Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# Airplane!                                          PG     Comedy  1980
# Caddyshack                                          R     Comedy  1980
# ...                                               ...        ...   ...
# More to Life                                      NaN      Drama  2020
# Dream Round                                       NaN     Comedy  2020
# Saving Mbango                                     NaN      Drama  2020
# It's Just Us                                      NaN      Drama  2020
# Tee em el                                         NaN     Horror  2020
#
#                                                     release_date  \
# name
# ...

# %%
df.loc['The Shining']
# Out:
# rating                           R
# genre                        Drama
# year                          1980
# release_date         June 13, 1980
# release_country      United States
# score                          8.4
# votes                     927000.0
# director           Stanley Kubrick
# writer                Stephen King
# star                Jack Nicholson
# country             United Kingdom
# budget                  19000000.0
# gross                   46998772.0
# company               Warner Bros.
# runtime                      146.0
# Name: The Shining, dtype: object

# %%
df_sort_budget = df.sort_values(by = 'budget',ascending=False)
df_sort_budget.head()
# Out:
#                                          rating   genre  year  \
# name
# Avengers: Endgame                         PG-13  Action  2019
# Avengers: Infinity War                    PG-13  Action  2018
# Star Wars: Episode VIII - The Last Jedi   PG-13  Action  2017
# Justice League                            PG-13  Action  2017
# Pirates of the Caribbean: at World's End  PG-13  Action  2007
#
#                                                release_date release_country  \
# name
# Avengers: Endgame                            April 26, 2019   United States
# Avengers: Infinity War                       April 27, 2018   United States
# Star Wars: Episode VIII - The Last Jedi   December 15, 2017   United States
# Justice League                            November 17, 2017   United States
# Pirates of the Caribbean: at World's End       May 25, 2007   United States
#
#                                           score     votes        director  \
# name
# ...

# %%
df_sort_budget[['budget','gross']].head(10)
# Out:
#                                                     budget         gross
# name
# Avengers: Endgame                              356000000.0  2.797501e+09
# Avengers: Infinity War                         321000000.0  2.048360e+09
# Star Wars: Episode VIII - The Last Jedi        317000000.0  1.332699e+09
# Justice League                                 300000000.0  6.579270e+08
# Pirates of the Caribbean: at World's End       300000000.0  9.609965e+08
# Star Wars: Episode IX - The Rise of Skywalker  275000000.0  1.078233e+09
# Solo: A Star Wars Story                        275000000.0  3.929248e+08
# Superman Returns                               270000000.0  3.910812e+08
# Tangled                                        260000000.0  5.924628e+08
# The Lion King                                  260000000.0  1.670728e+09

# %%
df_sort_gross = df.sort_values(by = 'gross',ascending=False)
df.head()
# Out:
#                                                rating      genre  year  \
# name
# The Shining                                         R      Drama  1980
# The Blue Lagoon                                     R  Adventure  1980
# Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# Airplane!                                          PG     Comedy  1980
# Caddyshack                                          R     Comedy  1980
#
#                                                  release_date release_country  \
# name
# The Shining                                     June 13, 1980   United States
# The Blue Lagoon                                  July 2, 1980   United States
# Star Wars: Episode V - The Empire Strikes Back  June 20, 1980   United States
# Airplane!                                        July 2, 1980   United States
# Caddyshack                                      July 25, 1980   United States
#
# ...

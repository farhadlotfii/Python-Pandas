# %%
import pandas as pd

# %%
df = pd.read_csv(r'..\S05-S08\Data\movies.csv',index_col='name')
df
# Out:
#                                                rating      genre  year  \
# name
# The Shining                                         R      Drama  1980
# The Blue Lagoon                                     R  Adventure  1980
# Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# Airplane!                                          PG     Comedy  1980
# Caddyshack                                          R     Comedy  1980
# ...                                               ...        ...   ...
# More to Life                                      NaN      Drama  2020
# Dream Round                                       NaN     Comedy  2020
# Saving Mbango                                     NaN      Drama  2020
# It's Just Us                                      NaN      Drama  2020
# Tee em el                                         NaN     Horror  2020
#
#                                                     release_date  \
# name
# ...

# %%
df['score']
# Out:
# name
# The Shining                                       8.4
# The Blue Lagoon                                   5.8
# Star Wars: Episode V - The Empire Strikes Back    8.7
# Airplane!                                         7.7
# Caddyshack                                        7.3
#                                                  ...
# More to Life                                      3.1
# Dream Round                                       4.7
# Saving Mbango                                     5.7
# It's Just Us                                      NaN
# Tee em el                                         5.7
# Name: score, Length: 7666, dtype: float64

# %%
df['score'] >= 0.9
# Out:
# name
# The Shining                                        True
# The Blue Lagoon                                    True
# Star Wars: Episode V - The Empire Strikes Back     True
# Airplane!                                          True
# Caddyshack                                         True
#                                                   ...
# More to Life                                       True
# Dream Round                                        True
# Saving Mbango                                      True
# It's Just Us                                      False
# Tee em el                                          True
# Name: score, Length: 7666, dtype: bool

# %%
mask1 = df['score'] >= 8.6
mask2 = df['score'] <= 8.9
df[mask1 & mask2].sort_values(by='score',ascending=False)
# Out:
#                                                   rating      genre  year  \
# name
# Schindler's List                                       R  Biography  1993
# Pulp Fiction                                           R      Crime  1994
# The Lord of the Rings: The Return of the King      PG-13     Action  2003
# Fight Club                                             R      Drama  1999
# Inception                                          PG-13     Action  2010
# Forrest Gump                                       PG-13      Drama  1994
# The Lord of the Rings: The Fellowship of the Ring  PG-13     Action  2001
# Goodfellas                                             R  Biography  1990
# The Lord of the Rings: The Two Towers              PG-13     Action  2002
# Star Wars: Episode V - The Empire Strikes Back        PG     Action  1980
# The Matrix                                             R     Action  1999
# The Green Mile                                         R      Crime  1999
# ...

# %%
high_score = df['score'] >= 8.5
after_2017 = df['year'] >= 2014

df[high_score & after_2017].sort_values(by='score',ascending=False)
# Out:
#              rating      genre  year      release_date release_country  score  \
# name
# Interstellar  PG-13  Adventure  2014  November 7, 2014   United States    8.6
# Parasite          R     Comedy  2019  November 8, 2019   United States    8.6
# Whiplash          R      Drama  2014  October 15, 2014     Philippines    8.5
#
#                   votes           director           writer  \
# name
# Interstellar  1600000.0  Christopher Nolan   Jonathan Nolan
# Parasite       631000.0       Bong Joon Ho     Bong Joon Ho
# Whiplash       749000.0    Damien Chazelle  Damien Chazelle
#
#                              star        country       budget        gross  \
# name
# Interstellar  Matthew McConaughey  United States  165000000.0  701729206.0
# Parasite             Kang-ho Song    South Korea   11400000.0  258908054.0
# Whiplash             Miles Teller  United States    3300000.0   49396747.0
#
#                          company  runtime
# name
# ...
